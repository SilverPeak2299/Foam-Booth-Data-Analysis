# %% [markdown]
# # Section 3 will focus on storing data in a PostgreSQL database (SupaBase)
# I have modeled the tables with the follwing EER diagram
# <br>
# <br>
# <img src= "images/database_eer.png" alt= "EER Diagram" style="height:400px">

# %% [markdown]
# From this I will define my tables as:
# Invoice(invoice_no (pk), customer_name, date, total_cost)
# Invoice_Item(item_id (PK), invoice_no (pk, fk), quantity, price, total_price, item_description)
